# %% [markdown]
# # Stat 184 Overwatch Analysis
#
# This notebook revisits the anlysis done on overwatch player data from 2016. This analysis included a gradient boosted rank prediction model, that was not trained properly and the hyperparameters were note tuned. The end goal is to have a partner script that can read model parameters and take in profile data as input in order to predict a player rank.

# %%
import pandas as pd

# %%
profile_data = pd.read_csv('./data/profileData.csv',sep=',')

# %%
profile_data.head()
# Out:
#      Battletags  Level Rating   K/D   KDA Win Pct  Kills/Game Elim/Game  \
# 0     OGE-31607  1,269  4,702  3.83  4.52   65.0%       28.07     28.07
# 1   Lilbow-2784  1,712  4,613  2.71  6.27   57.7%       20.57     20.57
# 2  Boostio-1538  1,142  4,590  3.07  3.45   58.4%       30.61     30.61
# 3   DANYE-21205    830  4,565  3.84  4.39   64.5%       30.19     30.19
# 4  MirroR-11144    549  4,555  4.73  7.42   55.6%       27.67     27.67
#
#   Damage/Game Healing/Game  ... Healing/Min Damage/Min Solo Kills Obj kills  \
# 0   10,182.04       622.19  ...        0.85     836.24        210     1,205
# 1    6,308.55     9,047.82  ...       11.76     491.88        167     2,219
# 2   11,772.92       414.92  ...        0.52     886.06        247       677
# 3   11,718.06        82.29  ...        0.12     986.00         94       244
# 4   11,806.96       932.00  ...        1.38   1,047.78         17       320
#
#   Final Blows Damage Done  Elims Environment Kills  MultiKills  Deaths
# ...
